# %% [markdown]
# ### CS334 Homework 3 (100 pts)
#
# Topic: Convolutional Neural Networks (CNNs)
#
# Reading material: Chapter 11 & 12
#
# Requirements:
# - Export as HTML (.html) and submit that file.
# - Show intermediate steps for all shape, parameter-count, and FLOP calculations.
# - Work independently.

# %% [markdown]
# ### 1. Consider a CNN that takes an input image of size `64 x 64 x 3`.
#
# Layer A is a convolutional layer with:
# - `16` filters
# - kernel size `4 x 4`
# - stride `2`
# - padding `1`
#
# Layer B is a max-pooling layer with:
# - kernel size `2 x 2`
# - stride `2`
# - no padding
#
# Compute:
# - (a) [10 pts] the output dimension after Layer A
# - (b) [10 pts] the output dimension after Layer B
# - (c) [10 pts] the number of learnable parameters in Layer A and Layer B.

# %% [markdown]
# Your Answer:

# %% [markdown]
# ### 2. A convolutional layer receives an input tensor of size `32 x 32 x 16`. It uses:
# - `32` filters
# - kernel size `5 x 5`
# - stride `1`
# - padding `2`
#
# Ignoring bias additions and activation-function cost, compute:
# - (a) [10 pts] the output dimension
# - (b) [10 pts] the number of multiply-accumulate operations (MACs)
# - (c) [10 pts] the number of FLOPs if `1 MAC = 2 FLOPs`

# %% [markdown]
# Your Answer:

# %% [markdown]
# ### 3. [20 pts] Consider the following PyTorch model:
#
# (Recommended reading material: Batch Normalization Section in Chapter 11)
#
# ```python
# import torch.nn as nn
#
# model = nn.Sequential(
#     nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
#     nn.BatchNorm2d(32),
#     nn.ReLU(),
#     nn.MaxPool2d(kernel_size=2, stride=2),
#     nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
#     nn.ReLU(),
#     nn.BatchNorm2d(64),
#     nn.AdaptiveAvgPool2d((1, 1))
# )
# ```
#
# Answer the following:
# - (a) [10 pts] For the first convolution block, is batch normalization applied before or after ReLU?
# - (b) [10 pts] For the second convolution block, is batch normalization applied before or after ReLU?
# - (c) [10 pts] During training, what statistics does batch normalization use?
# - (d) [10 pts] During evaluation, does batch normalization use the current mini-batch? If not, what does it use instead?

# %% [markdown]
# Your Answer:
